# %% [markdown]
# # Phase diagram for Cu-Sb-S family

# %%
from pylada.vasp import MassExtract
# %pylab inline
import hform
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def plot_phase_diagram(data_to_plot, species, range=[-1,-1], axis=[1,0], legend = False, showx=True, showy=True, name = False):
    """Helper function to plot phase diagrams"
    fig=plt.figure(figsize=(4,6))
    ax = fig.add_subplot(111)


    loc=list(np.linspace(-2,0,5))
    ax.xaxis.set_major_locator(FixedLocator(loc))
    ax.yaxis.set_major_locator(FixedLocator(loc))
    
    loc=list(np.linspace(-2,0,5))
    ax.xaxis.set_major_locator(FixedLocator(loc))
    col = {'Cu2S3Sn1': 'BlanchedAlmond',  'Cu3S4Sn1':'Cyan', 'Cu4S16Sn7':'r', "Cu4S4Sn1": 'g', "Cu4S32Sn15":'m',  
           'Cu1S2Sb1': 'BlanchedAlmond',  'Cu3S4Sb1':'Cyan', 'Cu12S13Sb4':'r', "Cu3S3Sb1": 'g',  
            "Cu2S1":'DeepSkyBlue','Cu1S1':'y',
           "S1Sn1":'LightSeaGreen',  "S2Sn1":'DarkSalmon',
            "S3Sb2":'LightSeaGreen', 
            'S': 'w', 'Cu': 'w', 'Sn': 'w', 'Sb': 'w',
           "Cu1S1Sn1": 'k', "Cu1S2Sn1": 'm'
            }
    col = ['k', 'r', 'b', 'g', 'y', 'c', 'm', 'DarkSalmon', 'LightSeaGreen', 'BlanchedAlmond', 'DeepSkyBlue']*40
    for i, key in enumerate(data_to_plot.keys()):
        
        if len(data_to_plot[key][1])>1:
            ax.fill(data_to_plot[key][axis[0]], data_to_plot[key][axis[1]], col[i], alpha=0.75, label = key)
            
            #print i, key, col[i]
    if legend:
        ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
        
    if showy:
      ax.set_ylabel(r'$\Delta\mu_{\mathrm{%s}}$ [eV]'%species[axis[1]], fontsize=25)
    else:    
        plt.setp(ax.get_yticklabels(), visible=False)
        
    if showx:
        ax.set_xlabel(r'$\Delta\mu_{\mathrm{%s}}$ [eV]'%species[axis[0]], fontsize=25)
    else:    
        plt.setp(ax.get_xticklabels(), visible=False)
        
    ax.axis(xmin=range[0], xmax=0, ymin =range[1], ymax=0)
    
    if name:
        savefig(name)
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True, shadow=True, ncol=5)

# %%
def convert_list_2_dict(list):
    return {el[0]:el[1] for el in list}

# %% [markdown]
# ##Machine leanring Cu-Sb/Sn-S

# %% [markdown]
# ###cusns not in training set

# %%
data1 = [['Cu5Sn5S90', -8.8404945258999668], ['Cu5Sn10S85', -16.471628185450005], ['Cu5Sn15S80', -22.610423883000053], ['Cu5Sn20S75', -27.388264691549978], ['Cu5Sn25S70', -30.868197283100063], ['Cu5Sn30S65', -33.112069528649982], ['Cu5Sn35S60', -34.195556839200016], ['Cu5Sn40S55', -34.212042274749919], ['Cu5Sn45S50', -33.272980092299996], ['Cu5Sn50S45', -31.506919141849998], ['Cu5Sn55S40', -29.058088654399938], ['Cu5Sn60S35', -26.085156306950008], ['Cu5Sn65S30', -22.760862812499916], ['Cu5Sn70S25', -19.273726760049968], ['Cu5Sn75S20', -15.834393892599996], ['Cu5
u65Sn30S5', -13.784751290849995], ['Cu70Sn5S25', -25.492792754449979], ['Cu70Sn10S20', -23.490321075999976], ['Cu70Sn15S15', -20.657192411549996], ['Cu70Sn20S10', -17.182812660099998], ['Cu70Sn25S5', -13.322019292649978], ['Cu75Sn5S20', -22.453862272799974], ['Cu75Sn10S15', -19.959950645350013], ['Cu75Sn15S10', -16.72610362889997], ['Cu75Sn20S5', -12.986401695450001], ['Cu80Sn5S15', -19.305068856149976], ['Cu80Sn10S10', -16.367552388700002], ['Cu80Sn15S5', -12.799399379249987], ['Cu85Sn5S10', -16.099488301500031], ['Cu85Sn10S5', -12.758962944050012], ['Cu90Sn5S5', -12.816839238849997],]

data0 = [
["S1", -0.0],
["Cu1", -0.0],
["Sn1", -0.0],
["Cu2S1", -0.802800],
["S1Sn1", -0.671139],
["Cu1S1", -0.632841],
["S2Sn1", -1.030523],
["Cu2S1", -0.802800],
["Cu10Sn3", -1.43],
["Cu6Sn5", -1.54],
["Cu5Sn4", -1.35],
["Cu1Sn1", -0.24],
["Cu3Sn1", -0.48],
]
species = ['Sn', 'Cu', 'S']

# %%
import re
r = re.compile("([a-zA-Z]+)([0-9]+)")
for d in data1:
    data = data0[:]
    d[-1] += 7
    data.append(d)
    data_to_plot = hform.get_phase_diagram(data, species=species)
    
    del data_to_plot['S']
    del data_to_plot['Sn']
    del data_to_plot['Cu']
    if len(data_to_plot[d[0]][0])>0:
        elements = r.findall(d[0])
       # print elements[0][1], elements[1][1], elements[2][1], 10*d[1]
        data[-1][-1] -= 7
        #print d, data_to_plot[d[0]]
        data_to_plot = hform.get_phase_diagram(data, species=species)
        plot_phase_diagram(data_to_plot, species, range=[-1.5, -1.5], axis=[1,0])

# %%
plot_phase_diagram(data_to_plot, species, range=[-1.5, -1.5], axis=[1,0],  name='ML_all_cusns.pdf')

# %%
count = 0 
for key, d in data_to_plot.items():
    #print d
    if len(d[0])>0:
        count +=1

# %% [markdown]
# ###cusns not in training set

# %%
data = [
["Cu2S3Sn1", -2.378810],
["Cu3S4Sn1", -3.084205],
["Cu4S16Sn7", -10.291798],
["Cu4S4Sn1", -3.330592],
["S1Sn1", -0.671139],
["Cu1S1", -0.632841],
["S2Sn1", -1.030523],
["Cu2S1", -0.802800],
["Cu4S32Sn15", -17.876377],
#["Cu1S1Sn1", -1.084113],
#["Cu1S2Sn1", -1.616289],

]
species = ['Sn', 'Cu', 'S']
data_to_plot = hform.get_phase_diagram(data, species=species)

del data_to_plot['S']
del data_to_plot['Sn']
del data_to_plot['Cu']


plot_phase_diagram(data_to_plot, species, range=[-0.9,-1.6], axis=[1,0], showx=False, name='ML_cusns.pdf')

# %% [markdown]
# ###cusns DFT, no FERE

# %%
mucu = 0.05
musn = 0.18
mus = 0.06
musb = -0.16

# %%
data = [
["Cu2S3Sn1", -3.024258924999998 + 2*mucu + 3*mus + musn],
["Cu3S4Sn1", -3.7802266300000014 + 3*mucu + 4*mus + musn],
["Cu4S16Sn7", -13.695827500000007 + 4*mucu + 16*mus + 7*musn],
["Cu4S4Sn1", -3.9527471666666685 + 4*mucu + 4*mus + musn],
["S1Sn1", -1.22 + mus + musn],
["Cu1S1", -0.68 + mucu + mus],
["S2Sn1", -1.69 + 2*mus + musn],
["Cu2S1", -0.9 + 2*mucu + mus],
["Cu4S32Sn15", -25.7338 + 4*mucu + 32*mus + 15*musn],
]

species = ['Sn', 'Cu', 'S']
data_to_plot = hform.get_phase_diagram(data, species=species)
plot_phase_diagram(data_to_plot, species, range=[-0.9,-1.6], axis=[1,0], showx=False, showy=False,  name='DFT_cusns.pdf')

# %%
data
# Out:
# [['Cu12S13Sb4', -9.040000000000001],
#  ['S3Sb2', -1.4602385924999992],
#  ['Cu3S3Sb1', -2.149985625000001],
#  ['Cu3S4Sb1', -2.524081045],
#  ['Cu1S1', -0.5700000000000001],
#  ['Cu2S1', -0.74],
#  ['Cu1S2Sb1', -1.2901129025000004]]

# %%
-9.0400000/29.
# Out:
# -0.31172413793103443

# %% [markdown]
# ###cusns not in training set

# %%
data = [
["Cu2S1", -0.802800],
["Cu1S1", -0.632841],
["Cu12S13Sb4", -8.987145],
["Cu3S3Sb1", -2.128015],
["Cu3S4Sb1", -2.559971],
["Cu1S2Sb1", -1.239473],
["S3Sb2", -1.270005],]
species = ['Sb', 'Cu', 'S']
data_to_plot = hform.get_phase_diagram(data, species=species)
plot_phase_diagram(data_to_plot, species, range=[-0.9,-1.6], axis=[1,0],  name='ML_cusbs.pdf')

# %%
###cusns DFT, no FERE

# %%
data = [
['Cu12S13Sb4', -9.78 + 12*mucu + 13*mus + 4*musb],
 ['S3Sb2', -1.320238592499999 + 3*mus + 2*musb],
 ['Cu3S3Sb1', -2.319985625000001 + 3*mucu + 3*mus + musb],
 ['Cu3S4Sb1', -2.7540810449999995 + 3*mucu + 4*mus + musb],
 ['Cu1S1', -0.68 + mucu + mus],
 ['Cu2S1', -0.9 + 2*mucu + mus],
 ['Cu1S2Sb1', -1.3001129025000004 + mucu + 2*mus + musb],
]
species = ['Sb', 'Cu', 'S']
data_to_plot = hform.get_phase_diagram(data, species=species)
plot_phase_diagram(data_to_plot, species, range=[-0.9,-1.6], axis=[1,0], showy=False,  name= 'DFT_cusbs.pdf')

# %%
# all convex hull

# %% [markdown]
# #DFT

# %% [markdown]
# ### Cu-Sb-S

# %%
second_dir = '/scratch/pzawadzk/materials'
species = ['Cu', 'Sb', 'S']
data = hform.get_hform(second_dir, species)

# %%
data
# Out:
# [['Cu12Sb4S13', -9.72937991500001],
#  ['Sb2S3', -1.320238592499999],
#  ['Sb4Cu11S13', -8.169762655],
#  ['Cu3Sb1', 0.12],
#  ['Sb4Cu12S13', -9.78096303000001],
#  ['Cu3Sb1S3', -2.319985625000001],
#  ['Cu3Sb1S4', -2.7540810449999995],
#  ['Cu1S1', -0.68],
#  ['Sb1Cu4S5', -3.191556500000001],
#  ['Cu2Sb1', -0.0],
#  ['Cu2S1', -0.9],
#  ['Cu1Sb1S2', -1.3001129025000004],
#  ['Sb8Cu23S26', -17.97017434]]

# %%
data_to_plot = hform.get_phase_diagram(data, species=species)

# %%
plot_phase_diagram(data_to_plot, species, range=[-1,-1], axis=[1,0])

# %% [raw]
# 36 CuSbS2 -> 3Cu12Sb4S13 + 2Sb(s) + 11 Sb2S3(s), dH0=3 eV or 21 meV/atom

# %% [raw]
# 3 CuSbS2 ->  Cu3SbS3 + Sb2S3, 22 meV/atom

# %% [raw]
# 2 CuSbS2 ->  Cu2S + Sb2S3, 47 meV/atom

# %% [raw]
# 9 CuSbS2 ->  3Cu3SbS4 + 2Sb + 2Sb2S3, 23 meV/atom

# %% [markdown]
# ### Cu-Sb-Se

# %%
second_dir = '/scratch/pzawadzk/materials'
species = ['Cu', 'Sb', 'Se']
data = hform.get_hform(second_dir, species)

# %%
data_to_plot = hform.get_phase_diagram(data, species=species)
plot_phase_diagram(data_to_plot, species, range=[-1,-1])

# %% [markdown]
# ### Cu-Sn-S

# %%
second_dir = '/scratch/pzawadzk/materials'
species = ['Cu', 'Sn', 'S']
data = hform.get_hform(second_dir, species)

# %%
data
# Out:
# [['Cu4Sn7S16', -13.695827500000007],
#  ['Cu4Sn1S4', -3.9527471666666685],
#  ['Sn1S1', -1.22],
#  ['Cu2Sn1S3', -3.024258924999998],
#  ['Cu1S1', -0.68],
#  ['Sn1S2', -1.59],
#  ['Cu3Sn1S4', -3.7802266300000014],
#  ['Cu2S1', -0.9]]

# %% [raw]
# Cu2Sn1S3                           -3.0295
# Cu3Sn1S4                           -3.7797
# Cu4Sn7S16                         -13.6898
# Cu4Sn1S4                           -3.9410
# Sn1S1                              -1.2200
# Cu1S1                              -0.6800
# Sn1S2                              -1.5900
# Cu2S1                              -0.9000
# Cu4Sn15S32                        -25.7338

# %%
data_to_plot = hform.get_phase_diagram(data, species=species)
plot_phase_diagram(data_to_plot, species, range=[-2,-1])

# %%
data_d = convert_list_2_dict(data)

# %%
data_d
# Out:
# {'Cu1S1': -0.68,
#  'Cu2S1': -0.9,
#  'Cu2Sn1S3': -3.024258924999998,
#  'Cu3Sn1S4': -3.7802266300000014,
#  'Cu4Sn1S4': -3.9527471666666685,
#  'Cu4Sn7S16': -13.695827500000007,
#  'Sn1S1': -1.22,
#  'Sn1S2': -1.59}

# %% [raw]
# Cu2SnS3 -> SnS + 2CuS

# %%
dH = data_d['Sn1S1'] + 2*data_d['Cu1S1'] - data_d['Cu2Sn1S3']
print dH
# Out:
# 0.444258925

# %% [raw]
# Cu2SnS3 -> SnS2 + Cu2S

# %%
dH = data_d['Sn1S2'] + data_d['Cu2S1'] - data_d['Cu2Sn1S3']
print dH
# Out:
# 0.534258925

# %% [raw]
# 3 Cu2SnS3 -> 2 Cu3SnS4 + SnS

# %%
dH = data_d['Sn1S1'] + 2*data_d['Cu3Sn1S4'] - 3*data_d['Cu2Sn1S3']
print dH
# Out:
# 0.292323515

# %% [raw]
# 2*Cu2SnS3 -> Cu4SnS4 + SnS2

# %%
dH = data_d['Sn1S2'] + data_d['Cu4Sn1S4'] - 2*data_d['Cu2Sn1S3']
print dH
# Out:
# 0.505770683333
